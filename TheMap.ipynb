# %%
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import matplotlib as mpl
import glob
import pandas as pd

# %%
import geopandas as gpd

# Provide the path to your shapefile (.shp)
shapefile_path = "/Users/anthonyguzman/Downloads/ca_county_boundaries/ca_county_boundaries.shp"

# Read the shapefile into a GeoDataFrame
california_counties = gpd.read_file(shapefile_path)
#print(data)

# Now 'data' contains your shapefile data as a GeoDataFrame

# %%
def plotMap(year):
    filtered_data= df[['Coordinate', year]].dropna()
    geometry = gpd.points_from_xy(filtered_data['Coordinate'].str.split(',').str[1].astype(float), filtered_data['Coordinate'].str.split(',').str[0].astype(float))
    gdf = gpd.GeoDataFrame(filtered_data, geometry=geometry)
    # Plot the GeoDataFrame on the existing GeoPandas plot
    fig, ax = plt.subplots(figsize=(10, 10))  # Create a new figure and axes
    california_counties.plot(ax=ax, color='lightgrey', edgecolor='black')  # Plot the existing map

    # Plot data points with marker size based on the value of each point
    gdf.plot(ax=ax, column=year, markersize=gdf[year]*10)  # Adjust marker size based on the value
    sm = plt.cm.ScalarMappable(cmap='rainbow', norm=plt.Normalize(vmin=0, vmax=df.max(numeric_only=True).max()))
    sm._A = []  # Fake up the array of the scalar mappable
    cbar = plt.colorbar(sm)

    # Setting the label for the colorbar
    cbar.set_label('Year')
    plt.title(f'Data for {year}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.show()

# %%
def createColorbar(df,year):
    fig, ax = plt.subplots(figsize=(6, 1))
    cmap = mpl.cm.rainbow
    #Change code so that it it fnds the maximum value in the ENTIRE array, not just a specific year.
    norm = mpl.colors.Normalize(vmin=0, vmax=df.max(numeric_only=True).max())

    cb = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                    norm=norm,
                                    orientation='vertical')
    cb.set_label('Number of Coextreme Days')
    plt.show()

# %%
california_counties.plot()
# Out:
# <Axes: >

# %% [markdown]
#  ### It must be noted that in order to create the following graphs, I ended up simply writing all the values by hand into an excel sheet, which I then fed into the machine to plot. In the future, you may want to have the computer keep track of all the data for each and every location across all time, but I was too tired to create yet another function, so I took the more tedious less intelectually taxing route.

# %%
df = pd.read_excel('MapCoordinates.xlsx',index_col=0)
year =2020

# %%
filtered_data= df[['Coordinate', year]].dropna()

# %% [markdown]
# ### I would suggest running the below cell, just to make sure everything is working order before immediatly overlsaying the scatterplot onto the geomap.

# %%
coordinates = filtered_data['Coordinate'].apply(lambda x: tuple(map(float, x.split(','))))

# Create a scatter plot
# Check if all the dots are in the right spot. NOTE: Longitude and lattitude
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.scatter([coord[1] for coord in coordinates], [coord[0] for coord in coordinates], c=filtered_data[year], cmap='rainbow', s=100, alpha=0.7)  # Plot the scatter plot
plt.colorbar(label=year)  # Add a colorbar indicating the data values
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Scatter Plot of Data for')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Simply write plotMap() with the year that you want to plot

# %%
plotMap(1999)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2000)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2001)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2002)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2003)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2004)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2005)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2006)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2007)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2008)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2009)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2010)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2011)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2012)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2012)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2013)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2014)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2015)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2016)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2017)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2018)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2019)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2020)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2021)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2022)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
plotMap(2023)
# Out:
# /var/folders/21/m_vgj_jx03d_1jzdffrlp2080000gn/T/ipykernel_12051/1316736338.py:14: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
filtered_data= df[['Coordinate', year]].dropna()
geometry = gpd.points_from_xy(filtered_data['Coordinate'].str.split(',').str[1].astype(float), filtered_data['Coordinate'].str.split(',').str[0].astype(float))
gdf = gpd.GeoDataFrame(filtered_data, geometry=geometry)

# Plot the GeoDataFrame on the existing GeoPandas plot
fig, ax = plt.subplots(figsize=(10, 10))  # Create a new figure and axes
california_counties.plot(ax=ax, color='lightgrey', edgecolor='black')  # Plot the existing map

# Plot data points with marker size based on the value of each point
gdf.plot(ax=ax, column=year, cmap='rainbow', markersize=gdf[year]*10, legend=True)  # Adjust marker size based on the value
plt.title(f'Data for {year}')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
year = 2019
filtered_data= df[['Coordinate', year]].dropna()
geometry = gpd.points_from_xy(filtered_data['Coordinate'].str.split(',').str[1].astype(float), filtered_data['Coordinate'].str.split(',').str[0].astype(float))
gdf = gpd.GeoDataFrame(filtered_data, geometry=geometry)

# Plot the GeoDataFrame on the existing GeoPandas plot
fig, ax = plt.subplots(figsize=(10, 10))  # Create a new figure and axes
california_counties.plot(ax=ax, color='lightgrey', edgecolor='black')  # Plot the existing map

# Plot data points with marker size based on the value of each point
gdf.plot(ax=ax, column=year, cmap='rainbow', markersize=gdf[year]*10, legend=True)  # Adjust marker size based on the value
plt.title(f'Data for {year}')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
